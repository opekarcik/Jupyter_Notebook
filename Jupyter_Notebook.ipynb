# %% [markdown]
# # Jupyter Notebook on IBM Watson Studio
# <img width="15%" height="15%" src="https://ibm.github.io/watson-studio-workshop/housing-price-predictor/assets/watson_logo.png">
#
#
# 100% Human
#
# This is an example of a markdown cell.
#
# Below is an example of quotation from Big DataVol. 1, No. 1, DOI:10.1089/big.2013.1508.
#
# > "At a high level, data science is a set of fundamental principles that support and guide the principled extraction of information and knowledge from data. Possibly the most closely related concept to data science is data mining—the actual extraction of knowledge from data via technologies that incorporate these principles. There are hundreds of different data-mining algorithms, and a great deal of detail to the methods of the field. We argue that underlying all these many details is a much smaller and more concise set of fundamental principles."
#
# <a href="https://doi.org/10.1089/big.2013.1508">This is an example of a working HTML URL link script within the markdown cell.

# %% [markdown]
# ### Random Walk
# <img src="https://i.postimg.cc/J0KDrSFF/random-walk.png">
#
# #### Following code simulates 10 000 times random walk given the constraints above using Python with numpy & matplotlib packages and calculates the odds of ending above the 80th step.

# %%
# Random Walk

import numpy as np
import matplotlib.pyplot as plt

np.random.seed(123)

# Initialize random_walk
all_walks = []
simulations = 10000

for i in range(simulations) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
            
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.title("PLOT")
plt.show()
ends = np_aw_t[-1,:]
plt.title("HISTOGRAM")
plt.hist(ends)
plt.show()

n = len(ends[ends >= 80])
chances = n / simulations * 100
print("Chances of success that we end up at least on 80th step: " + str(chances) + "%")
# Out:
# Chances of success that we end up at least on 80th step: 40.239999999999995%

# %% [markdown]
# ## Project Report List
# 1. Cover page: Title, affiliation, author name, date of publication and contact.
# 2. Table of contents: Headlines of each section, lists of tables and figures.
# 3. Introduction: Abstract or brief introductory/executive summary of the project.
# 4. Methodology: Sources of data and description of methods used.
# 5. Results: Presentation of main empirical findings.
# 6. Discussion: Communicating thesis to readers while referring to research question and highlighting findings.
# 7. Conclusion: Presenting generalized specific findings & identification of possible future implementations and development of results and findings.
# 8. References: All the materials used in the project should be referenced.
# 9. Acknowledgments: List of contributors of other individuals to the project.
# 10. Appendices: If applicable.

# %% [markdown]
# Colons can be used to align columns.
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned | $1600 |
# | col 2 is      | centered      |   $12 |
# | zebra stripes | are neat      |    $1 |
#
# There must be at least 3 dashes separating each header cell.
# The outer pipes (|) are optional, and you don't need to make the
# raw Markdown line up prettily. You can also use inline Markdown.
#
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3

# %% [markdown]
# <i>Thank you for reading.</i>
#
# This marks the END.
